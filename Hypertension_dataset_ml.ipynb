# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#data import 
hypr_df = pd.read_csv("hypertension_data.csv")

# %%
hypr_df.head()
#numerical - age,trestbps,chol,thalach,oldpeak,
#num_cat - cp,fbs,restecg,exang,slope,ca,thal
#target - target
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  57.0  1.0   3       145   233    1        0      150      0      2.3
# 1  64.0  0.0   2       130   250    0        1      187      0      3.5
# 2  52.0  1.0   1       130   204    0        0      172      0      1.4
# 3  56.0  0.0   1       120   236    0        1      178      0      0.8
# 4  66.0  0.0   0       120   354    0        1      163      1      0.6
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1

# %%
hypr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26083 entries, 0 to 26082
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       26083 non-null  float64
#  1   sex       26058 non-null  float64
#  2   cp        26083 non-null  int64
#  3   trestbps  26083 non-null  int64
#  4   chol      26083 non-null  int64
#  5   fbs       26083 non-null  int64
#  6   restecg   26083 non-null  int64
#  7   thalach   26083 non-null  int64
#  8   exang     26083 non-null  int64
#  9   oldpeak   26083 non-null  float64
#  10  slope     26083 non-null  int64
#  11  ca        26083 non-null  int64
#  12  thal      26083 non-null  int64
#  13  target    26083 non-null  int64
# dtypes: float64(3), int64(11)
# memory usage: 2.8 MB

# %%
hypr_df.describe()
# Out:
#                 age          sex            cp      trestbps          chol  \
# count  26083.000000  26058.00000  26083.000000  26083.000000  26083.000000
# mean      55.661389      0.50000      0.958594    131.592992    246.246061
# std       15.189768      0.50001      1.023931     17.588809     51.643522
# min       11.000000      0.00000      0.000000     94.000000    126.000000
# 25%       44.000000      0.00000      0.000000    120.000000    211.000000
# 50%       56.000000      0.50000      1.000000    130.000000    240.000000
# 75%       67.000000      1.00000      2.000000    140.000000    275.000000
# max       98.000000      1.00000      3.000000    200.000000    564.000000
#
#                 fbs       restecg       thalach         exang       oldpeak  \
# count  26083.000000  26083.000000  26083.000000  26083.000000  26083.000000
# mean       0.149753      0.526512    149.655024      0.326573      1.039512
# ...

# %%
sns.pairplot(hypr_df,hue="target",palette="magma")
# Out:
# C:\Users\dines\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
facet_kws={"hue":"target","palette":{0:"red",1:"blue"}}
sns.displot(x="thalach",col="target",data=hypr_df,alpha=0.6,**facet_kws,bins=30)
sns.set_style("white")
#higher average of thalch in target(1)
# Out:
# C:\Users\dines\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.countplot(x="cp",data=hypr_df,hue="target",palette="viridis")
sns.set_style("white")
sns.despine()
plt.grid()
#most count of target(0) in cp(0) and of target(1) in cp(1)

# %%
facet_kws = {"hue":"target","palette":{0:"red",1:"blue"}}
sns.displot(x="trestbps",col="target",data=hypr_df,alpha=0.6,**facet_kws,bins=30)
#higher values of trestbps seen in target(1)
# Out:
# C:\Users\dines\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.countplot(x="thal",data=hypr_df,hue="target",palette="viridis")
plt.grid()
sns.despine()
#higher count of thal(2) in target(0) and thal(3) in target(1)

# %%
sns.heatmap(hypr_df.corr(),cmap="coolwarm")
#no correlation and also negative correleation seen in features
# Out:
# <Axes: >

# %%
sns.countplot(x="slope",hue="target",palette="viridis",data=hypr_df)
plt.grid()
sns.despine()

# %%
sns.countplot(x="ca",data=hypr_df,hue="target",palette="viridis")
# Out:
# <Axes: xlabel='ca', ylabel='count'>

# %%
sns.violinplot(x="target",y="age",hue="sex",data=hypr_df,palette="viridis")
#equal dist of age and sex in both target classes
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
facet_kws = {"hue":"target","palette":{0:"red",1:"blue"}}
sns.displot(x="oldpeak",col="target",data=hypr_df,**facet_kws,bins=30,alpha=0.6)
#high cases of oldpeak(0) in target(1)
# Out:
# C:\Users\dines\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.countplot(x="exang",hue="target",palette="viridis",data=hypr_df)
# Out:
# <Axes: xlabel='exang', ylabel='count'>

# %%
sns.countplot(x="fbs",hue="target",palette="viridis",data=hypr_df)
# Out:
# <Axes: xlabel='fbs', ylabel='count'>

# %%
sns.countplot(x="restecg",hue="target",palette="viridis",data=hypr_df)
#high cases of resecg(0) in target(1) and restecg(1) in target(0)
# Out:
# <Axes: xlabel='restecg', ylabel='count'>

# %%
facet_kws = {"hue":"target","palette":{0:"red",1:"blue"}}
sns.displot(x="chol",col="target",data=hypr_df,**facet_kws,bins=30,alpha=0.6)
#higher cases of cholestrol in range(200-300) for target(1)
# Out:
# C:\Users\dines\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#visualization is complete
#data split
from sklearn.model_selection import train_test_split
X = hypr_df.drop("target",axis=1)
y= hypr_df["target"]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33)

# %%
#models to test
#Rfc,Dtree,Svm,log_reg,knn,
hypr_df.dropna(inplace=True)

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import classification_report,confusion_matrix
pred_dtree = dtree.predict(X_test)
print(classification_report(y_test,pred_dtree))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3841
#            1       1.00      1.00      1.00      4759
#
#     accuracy                           1.00      8600
#    macro avg       1.00      1.00      1.00      8600
# weighted avg       1.00      1.00      1.00      8600

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train,y_train)
pred_rfc = rfc.predict(X_test)
print(classification_report(y_test,pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3841
#            1       1.00      1.00      1.00      4759
#
#     accuracy                           1.00      8600
#    macro avg       1.00      1.00      1.00      8600
# weighted avg       1.00      1.00      1.00      8600
